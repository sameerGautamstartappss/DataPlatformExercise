# %%
print("Jupyter is working")
# Out:
# Jupyter is working

# %%
import pandas as pd
import numpy as np
print("Pandas and numpy are working too")
# Out:
# Pandas and numpy are working too

# %%
import mysql.connector

conn = mysql.connector.connect(
    host ="mysql_container1",
    user ="projectuser",
    password = "projectpass",
    database = "projectdb"
)

cursor = conn.cursor()
cursor.execute("SHOW TABLES;")
# cursor.execute("SHOW DATABASES;")
print(cursor.fetchall())
conn.close()
# Out:
# [('customers',)]
